# %%
import pandas as pd

# %%
# bring edited csv back in to separate genres
bp_full_df = pd.read_csv('with_producers.csv')
bp_full_df
# Out:
#                      title  runtime     rating                        genre  \
# 0              Jojo Rabbit  108 min      PG-13           Comedy, Drama, War
# 1           Marriage Story  137 min          R               Drama, Romance
# 2             The Irishman  209 min          R      Biography, Crime, Drama
# 3                 Parasite  132 min          R      Comedy, Drama, Thriller
# 4             Little Women  135 min         PG               Drama, Romance
# ..                     ...      ...        ...                          ...
# 329   Mutiny on the Bounty  178 min  Not Rated    Adventure, Drama, History
# 330          The Music Man  151 min          G      Comedy, Family, Musical
# 331        The Longest Day  178 min          G       Action, Drama, History
# 332     Lawrence of Arabia  218 min   Approved  Adventure, Biography, Drama
# 333  To Kill a Mockingbird  129 min   Approved                 Crime, Drama
#
#                                                summary           gross  \
# 0    A young German boy in the Hitler Youth whose h...      349,555.00
# 1    Noah Baumbach's incisive and compassionate loo...    2,000,000.00
# 2    Hitman Frank Sheeran looks back at the secrets...    7,000,000.00
# 3    Greed and class discrimination threaten the ne...   53,367,844.00
# 4    Jo March reflects back and forth on her life, ...  108,101,214.00
# ..                                                 ...             ...
# 329  In 1787, British ship Bounty leaves Portsmouth...   13,680,000.00
# 330  Traveling con artist Harold Hill targets the n...   14,953,846.00
# 331  The events of D-Day, told on a grand scale fro...   39,100,000.00
# 332  The story of T.E. Lawrence, the English office...   44,824,144.00
# 333  Atticus Finch, a widowed lawyer in Depression-...      592,237.00
#
#      release_year_x      category  oscar_year  winner                   film  \
# 0              2019  Best Picture        2020       0            Jojo Rabbit
# 1              2019  Best Picture        2020       0         Marriage Story
# 2              2019  Best Picture        2020       0           The Irishman
# 3              2019  Best Picture        2020       1               Parasite
# 4              2019  Best Picture        2020       0           Little Women
# ..              ...           ...         ...     ...                    ...
# 329            1962  Best Picture        1963       0   Mutiny on the Bounty
# 330            1962  Best Picture        1963       0          The Music Man
# 331            1962  Best Picture        1963       0        The Longest Day
# 332            1962  Best Picture        1963       1     Lawrence of Arabia
# 333            1962  Best Picture        1963       0  To Kill a Mockingbird
#
#                                               producer
# 0    Carthew Neal, Taika Waititi, and Chelsea Winst...
# 1                       Noah Baumbach and David Heyman
# 2    Martin Scorsese, Robert De Niro, Jane Rosentha...
# 3                         Kwak Sin-ae and Bong Joon-ho
# 4                                           Amy Pascal
# ..                                                 ...
# 329                                    Aaron Rosenberg
# 330                                    Morton Da Costa
# 331                                   Darryl F. Zanuck
# 332                                        Sam Spiegel
# 333                                     Alan J. Pakula
#
# [334 rows x 12 columns]

# %%
# split genre column into multiples
genres = bp_full_df['genre'].str.split(pat =',', expand=True)
genres
# Out:
#              0           1          2
# 0       Comedy       Drama        War
# 1        Drama     Romance       None
# 2    Biography       Crime      Drama
# 3       Comedy       Drama   Thriller
# 4        Drama     Romance       None
# ..         ...         ...        ...
# 329  Adventure       Drama    History
# 330     Comedy      Family    Musical
# 331     Action       Drama    History
# 332  Adventure   Biography      Drama
# 333      Crime       Drama       None
#
# [334 rows x 3 columns]

# %%
genres = genres.rename(columns={0:'genre_1', 1:'genre_2', 2:'genre_3'})
genres
# Out:
#        genre_1     genre_2    genre_3
# 0       Comedy       Drama        War
# 1        Drama     Romance       None
# 2    Biography       Crime      Drama
# 3       Comedy       Drama   Thriller
# 4        Drama     Romance       None
# ..         ...         ...        ...
# 329  Adventure       Drama    History
# 330     Comedy      Family    Musical
# 331     Action       Drama    History
# 332  Adventure   Biography      Drama
# 333      Crime       Drama       None
#
# [334 rows x 3 columns]

# %%
#add genre df to bp_full_df based on index
bp_full_df = pd.concat([bp_full_df, genres], axis=1)
bp_full_df
# Out:
#                      title  runtime     rating                        genre  \
# 0              Jojo Rabbit  108 min      PG-13           Comedy, Drama, War
# 1           Marriage Story  137 min          R               Drama, Romance
# 2             The Irishman  209 min          R      Biography, Crime, Drama
# 3                 Parasite  132 min          R      Comedy, Drama, Thriller
# 4             Little Women  135 min         PG               Drama, Romance
# ..                     ...      ...        ...                          ...
# 329   Mutiny on the Bounty  178 min  Not Rated    Adventure, Drama, History
# 330          The Music Man  151 min          G      Comedy, Family, Musical
# 331        The Longest Day  178 min          G       Action, Drama, History
# 332     Lawrence of Arabia  218 min   Approved  Adventure, Biography, Drama
# 333  To Kill a Mockingbird  129 min   Approved                 Crime, Drama
#
#                                                summary           gross  \
# 0    A young German boy in the Hitler Youth whose h...      349,555.00
# 1    Noah Baumbach's incisive and compassionate loo...    2,000,000.00
# 2    Hitman Frank Sheeran looks back at the secrets...    7,000,000.00
# 3    Greed and class discrimination threaten the ne...   53,367,844.00
# 4    Jo March reflects back and forth on her life, ...  108,101,214.00
# ..                                                 ...             ...
# 329  In 1787, British ship Bounty leaves Portsmouth...   13,680,000.00
# 330  Traveling con artist Harold Hill targets the n...   14,953,846.00
# 331  The events of D-Day, told on a grand scale fro...   39,100,000.00
# 332  The story of T.E. Lawrence, the English office...   44,824,144.00
# 333  Atticus Finch, a widowed lawyer in Depression-...      592,237.00
#
#      release_year_x      category  oscar_year  winner                   film  \
# 0              2019  Best Picture        2020       0            Jojo Rabbit
# 1              2019  Best Picture        2020       0         Marriage Story
# 2              2019  Best Picture        2020       0           The Irishman
# 3              2019  Best Picture        2020       1               Parasite
# 4              2019  Best Picture        2020       0           Little Women
# ..              ...           ...         ...     ...                    ...
# 329            1962  Best Picture        1963       0   Mutiny on the Bounty
# 330            1962  Best Picture        1963       0          The Music Man
# 331            1962  Best Picture        1963       0        The Longest Day
# 332            1962  Best Picture        1963       1     Lawrence of Arabia
# 333            1962  Best Picture        1963       0  To Kill a Mockingbird
#
#                                               producer    genre_1     genre_2  \
# 0    Carthew Neal, Taika Waititi, and Chelsea Winst...     Comedy       Drama
# 1                       Noah Baumbach and David Heyman      Drama     Romance
# 2    Martin Scorsese, Robert De Niro, Jane Rosentha...  Biography       Crime
# 3                         Kwak Sin-ae and Bong Joon-ho     Comedy       Drama
# 4                                           Amy Pascal      Drama     Romance
# ..                                                 ...        ...         ...
# 329                                    Aaron Rosenberg  Adventure       Drama
# 330                                    Morton Da Costa     Comedy      Family
# 331                                   Darryl F. Zanuck     Action       Drama
# 332                                        Sam Spiegel  Adventure   Biography
# 333                                     Alan J. Pakula      Crime       Drama
#
#        genre_3
# 0          War
# 1         None
# 2        Drama
# 3     Thriller
# 4         None
# ..         ...
# 329    History
# 330    Musical
# 331    History
# 332      Drama
# 333       None
#
# [334 rows x 15 columns]

# %%
bp_full_df = bp_full_df.rename(columns = {'release_year_x':'release_year'})
bp_full_df.head()
# Out:
#             title  runtime rating                    genre  \
# 0     Jojo Rabbit  108 min  PG-13       Comedy, Drama, War
# 1  Marriage Story  137 min      R           Drama, Romance
# 2    The Irishman  209 min      R  Biography, Crime, Drama
# 3        Parasite  132 min      R  Comedy, Drama, Thriller
# 4    Little Women  135 min     PG           Drama, Romance
#
#                                              summary           gross  \
# 0  A young German boy in the Hitler Youth whose h...      349,555.00
# 1  Noah Baumbach's incisive and compassionate loo...    2,000,000.00
# 2  Hitman Frank Sheeran looks back at the secrets...    7,000,000.00
# 3  Greed and class discrimination threaten the ne...   53,367,844.00
# 4  Jo March reflects back and forth on her life, ...  108,101,214.00
#
#    release_year      category  oscar_year  winner            film  \
# 0          2019  Best Picture        2020       0     Jojo Rabbit
# 1          2019  Best Picture        2020       0  Marriage Story
# 2          2019  Best Picture        2020       0    The Irishman
# 3          2019  Best Picture        2020       1        Parasite
# 4          2019  Best Picture        2020       0    Little Women
#
#                                             producer    genre_1   genre_2  \
# 0  Carthew Neal, Taika Waititi, and Chelsea Winst...     Comedy     Drama
# 1                     Noah Baumbach and David Heyman      Drama   Romance
# 2  Martin Scorsese, Robert De Niro, Jane Rosentha...  Biography     Crime
# 3                       Kwak Sin-ae and Bong Joon-ho     Comedy     Drama
# 4                                         Amy Pascal      Drama   Romance
#
#      genre_3
# 0        War
# 1       None
# 2      Drama
# 3   Thriller
# 4       None

# %%
#clean runtime, int only
bp_full_df['runtime_min'] = bp_full_df['runtime'].str.extract('(.*)\s')
bp_full_df = bp_full_df.drop(columns={'runtime'})
bp_full_df['runtime_min'] = pd.to_numeric(bp_full_df['runtime_min'])
#verify
bp_full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334 entries, 0 to 333
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         334 non-null    object
#  1   rating        334 non-null    object
#  2   genre         334 non-null    object
#  3   summary       334 non-null    object
#  4   gross         325 non-null    object
#  5   release_year  334 non-null    int64
#  6   category      334 non-null    object
#  7   oscar_year    334 non-null    int64
#  8   winner        334 non-null    int64
#  9   film          334 non-null    object
#  10  producer      334 non-null    object
#  11  genre_1       334 non-null    object
#  12  genre_2       298 non-null    object
#  13  genre_3       202 non-null    object
#  14  runtime_min   334 non-null    int64
# dtypes: int64(4), object(11)
# memory usage: 39.3+ KB

# %%
bp_full_df['gross'] = bp_full_df['gross'].str.replace(',', '')
bp_full_df['gross'] = bp_full_df['gross'].str.replace('\.00', '')
bp_full_df
# Out:
# C:\Users\zoete\AppData\Local\Temp\ipykernel_19000\2626593479.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   bp_full_df['gross'] = bp_full_df['gross'].str.replace('\.00', '')
#                      title     rating                        genre  \
# 0              Jojo Rabbit      PG-13           Comedy, Drama, War
# 1           Marriage Story          R               Drama, Romance
# 2             The Irishman          R      Biography, Crime, Drama
# 3                 Parasite          R      Comedy, Drama, Thriller
# 4             Little Women         PG               Drama, Romance
# ..                     ...        ...                          ...
# 329   Mutiny on the Bounty  Not Rated    Adventure, Drama, History
# 330          The Music Man          G      Comedy, Family, Musical
# 331        The Longest Day          G       Action, Drama, History
# 332     Lawrence of Arabia   Approved  Adventure, Biography, Drama
# 333  To Kill a Mockingbird   Approved                 Crime, Drama
#
#                                                summary      gross  \
# 0    A young German boy in the Hitler Youth whose h...     349555
# 1    Noah Baumbach's incisive and compassionate loo...    2000000
# 2    Hitman Frank Sheeran looks back at the secrets...    7000000
# 3    Greed and class discrimination threaten the ne...   53367844
# 4    Jo March reflects back and forth on her life, ...  108101214
# ..                                                 ...        ...
# 329  In 1787, British ship Bounty leaves Portsmouth...   13680000
# 330  Traveling con artist Harold Hill targets the n...   14953846
# 331  The events of D-Day, told on a grand scale fro...   39100000
# 332  The story of T.E. Lawrence, the English office...   44824144
# 333  Atticus Finch, a widowed lawyer in Depression-...     592237
#
#      release_year      category  oscar_year  winner                   film  \
# 0            2019  Best Picture        2020       0            Jojo Rabbit
# 1            2019  Best Picture        2020       0         Marriage Story
# 2            2019  Best Picture        2020       0           The Irishman
# 3            2019  Best Picture        2020       1               Parasite
# 4            2019  Best Picture        2020       0           Little Women
# ..            ...           ...         ...     ...                    ...
# 329          1962  Best Picture        1963       0   Mutiny on the Bounty
# 330          1962  Best Picture        1963       0          The Music Man
# 331          1962  Best Picture        1963       0        The Longest Day
# 332          1962  Best Picture        1963       1     Lawrence of Arabia
# 333          1962  Best Picture        1963       0  To Kill a Mockingbird
#
#                                               producer    genre_1     genre_2  \
# 0    Carthew Neal, Taika Waititi, and Chelsea Winst...     Comedy       Drama
# 1                       Noah Baumbach and David Heyman      Drama     Romance
# 2    Martin Scorsese, Robert De Niro, Jane Rosentha...  Biography       Crime
# 3                         Kwak Sin-ae and Bong Joon-ho     Comedy       Drama
# 4                                           Amy Pascal      Drama     Romance
# ..                                                 ...        ...         ...
# 329                                    Aaron Rosenberg  Adventure       Drama
# 330                                    Morton Da Costa     Comedy      Family
# 331                                   Darryl F. Zanuck     Action       Drama
# 332                                        Sam Spiegel  Adventure   Biography
# 333                                     Alan J. Pakula      Crime       Drama
#
#        genre_3  runtime_min
# 0          War          108
# 1         None          137
# 2        Drama          209
# 3     Thriller          132
# 4         None          135
# ..         ...          ...
# 329    History          178
# 330    Musical          151
# 331    History          178
# 332      Drama          218
# 333       None          129
#
# [334 rows x 15 columns]

# %%
bp_full_df['gross'] = bp_full_df['gross'].astype('Int32')
bp_full_df.head()
# Out:
#             title rating                    genre  \
# 0     Jojo Rabbit  PG-13       Comedy, Drama, War
# 1  Marriage Story      R           Drama, Romance
# 2    The Irishman      R  Biography, Crime, Drama
# 3        Parasite      R  Comedy, Drama, Thriller
# 4    Little Women     PG           Drama, Romance
#
#                                              summary      gross  release_year  \
# 0  A young German boy in the Hitler Youth whose h...     349555          2019
# 1  Noah Baumbach's incisive and compassionate loo...    2000000          2019
# 2  Hitman Frank Sheeran looks back at the secrets...    7000000          2019
# 3  Greed and class discrimination threaten the ne...   53367844          2019
# 4  Jo March reflects back and forth on her life, ...  108101214          2019
#
#        category  oscar_year  winner            film  \
# 0  Best Picture        2020       0     Jojo Rabbit
# 1  Best Picture        2020       0  Marriage Story
# 2  Best Picture        2020       0    The Irishman
# 3  Best Picture        2020       1        Parasite
# 4  Best Picture        2020       0    Little Women
#
#                                             producer    genre_1   genre_2  \
# 0  Carthew Neal, Taika Waititi, and Chelsea Winst...     Comedy     Drama
# 1                     Noah Baumbach and David Heyman      Drama   Romance
# 2  Martin Scorsese, Robert De Niro, Jane Rosentha...  Biography     Crime
# 3                       Kwak Sin-ae and Bong Joon-ho     Comedy     Drama
# 4                                         Amy Pascal      Drama   Romance
#
#      genre_3  runtime_min
# 0        War          108
# 1       None          137
# 2      Drama          209
# 3   Thriller          132
# 4       None          135

# %%
#save new df as csv to import to SQL
bp_full_df.to_csv('bp_clean.csv', index=False)

# %%
#What's the most frequent primary genre? Drama
bp_full_df['genre_1'].value_counts()
# Out:
# Drama        113
# Biography     75
# Comedy        58
# Action        29
# Crime         29
# Adventure     23
# Animation      3
# Horror         2
# Sci-Fi         1
# Western        1
# Name: genre_1, dtype: int64

# %%
bp_full_df['genre_2'].value_counts()
# Out:
#  Drama        149
#  Romance       36
#  Adventure     17
#  Crime         16
#  Comedy        14
#  Mystery        9
#  Family         9
#  Thriller       8
#  Biography      7
#  History        7
#  Music          6
#  Fantasy        6
#  War            5
#  Western        3
#  Musical        2
#  Sci-Fi         2
#  Sport          2
# Name: genre_2, dtype: int64

# %%
bp_full_df['genre_3'].value_counts()
# Out:
#  Drama       37
#  Romance     35
#  History     32
#  Thriller    26
#  War         15
#  Music        9
#  Fantasy      8
#  Musical      8
#  Sci-Fi       7
#  Mystery      6
#  Sport        6
#  Crime        5
#  Family       5
#  Comedy       2
#  Western      1
# Name: genre_3, dtype: int64

# %%
winners = bp_full_df.query('winner == 1')
winners.head()
# Out:
#                  title rating                     genre  \
# 3             Parasite      R   Comedy, Drama, Thriller
# 13          Green Book  PG-13  Biography, Comedy, Drama
# 22  The Shape of Water      R   Drama, Fantasy, Romance
# 27           Moonlight      R                     Drama
# 37           Spotlight      R   Biography, Crime, Drama
#
#                                               summary     gross  release_year  \
# 3   Greed and class discrimination threaten the ne...  53367844          2019
# 13  A working-class Italian-American bouncer becom...  85080171          2018
# 22  At a top secret research facility in the 1960s...  63859435          2017
# 27  A young African-American man grapples with his...  27854932          2016
# 37  The true story of how the Boston Globe uncover...  45055776          2015
#
#         category  oscar_year  winner                film  \
# 3   Best Picture        2020       1            Parasite
# 13  Best Picture        2019       1          Green Book
# 22  Best Picture        2018       1  The Shape of Water
# 27  Best Picture        2017       1           Moonlight
# 37  Best Picture        2016       1           Spotlight
#
#                                              producer    genre_1   genre_2  \
# 3                        Kwak Sin-ae and Bong Joon-ho     Comedy     Drama
# 13  Jim Burke, Charles B. Wessler, Brian Currie, P...  Biography    Comedy
# 22               Guillermo del Toro and J. Miles Dale      Drama   Fantasy
# 27   Adele Romanski, Dede Gardner, and Jeremy Kleiner      Drama      None
# 37  Blye Pagon Faust, Steve Golin, Nicole Rocklin,...  Biography     Crime
#
#       genre_3  runtime_min
# 3    Thriller          132
# 13      Drama          130
# 22    Romance          123
# 27       None          111
# 37      Drama          129

# %%
losers = bp_full_df.query('winner == 0')
losers.head()
# Out:
#             title rating                     genre  \
# 0     Jojo Rabbit  PG-13        Comedy, Drama, War
# 1  Marriage Story      R            Drama, Romance
# 2    The Irishman      R   Biography, Crime, Drama
# 4    Little Women     PG            Drama, Romance
# 5  Ford v Ferrari  PG-13  Action, Biography, Drama
#
#                                              summary      gross  release_year  \
# 0  A young German boy in the Hitler Youth whose h...     349555          2019
# 1  Noah Baumbach's incisive and compassionate loo...    2000000          2019
# 2  Hitman Frank Sheeran looks back at the secrets...    7000000          2019
# 4  Jo March reflects back and forth on her life, ...  108101214          2019
# 5  American car designer Carroll Shelby and drive...  117624028          2019
#
#        category  oscar_year  winner            film  \
# 0  Best Picture        2020       0     Jojo Rabbit
# 1  Best Picture        2020       0  Marriage Story
# 2  Best Picture        2020       0    The Irishman
# 4  Best Picture        2020       0    Little Women
# 5  Best Picture        2020       0  Ford v Ferrari
#
#                                             producer    genre_1     genre_2  \
# 0  Carthew Neal, Taika Waititi, and Chelsea Winst...     Comedy       Drama
# 1                     Noah Baumbach and David Heyman      Drama     Romance
# 2  Martin Scorsese, Robert De Niro, Jane Rosentha...  Biography       Crime
# 4                                         Amy Pascal      Drama     Romance
# 5    Peter Chernin, Jenno Topping, and James Mangold     Action   Biography
#
#   genre_3  runtime_min
# 0     War          108
# 1    None          137
# 2   Drama          209
# 4    None          135
# 5   Drama          152

# %%
#genre most won - R
perc_genre_won = pd.DataFrame(winners['rating'].value_counts()).reset_index().rename(columns={'rating':'count', 'index':'rating'})
perc_genre_won['total_won'] = winners['title'].count()
perc_genre_won['percent'] = perc_genre_won['count']/perc_genre_won['total_won']*100
perc_genre_won
# Out:
#       rating  count  total_won    percent
# 0          R     32         59  54.237288
# 1      PG-13     10         59  16.949153
# 2         PG      9         59  15.254237
# 3          G      4         59   6.779661
# 4   Approved      2         59   3.389831
# 5         GP      1         59   1.694915
# 6  Not Rated      1         59   1.694915

# %%
#genre most lost - R
perc_genre_lost = pd.DataFrame(losers['rating'].value_counts()).reset_index().rename(columns={'rating':'count', 'index':'rating'})
perc_genre_lost['total_lost'] = losers['title'].count()
perc_genre_lost['percent'] = perc_genre_lost['count']/perc_genre_lost['total_lost']*100
perc_genre_lost
# Out:
#       rating  count  total_lost    percent
# 0          R    126         275  45.818182
# 1      PG-13     64         275  23.272727
# 2         PG     57         275  20.727273
# 3          G     13         275   4.727273
# 4  Not Rated      5         275   1.818182
# 5   Approved      4         275   1.454545
# 6    Unrated      3         275   1.090909
# 7         GP      1         275   0.363636
# 8       M/PG      1         275   0.363636
# 9      TV-MA      1         275   0.363636

# %%
#Average runtime of winners is longer than avg runtime of losers
print('winner_avg_runtime:')
print(winners['runtime_min'].mean())
print('loser_avg_runtime:')
print(losers['runtime_min'].mean())
# Out:
# winner_avg_runtime:
# 140.74576271186442
# loser_avg_runtime:
# 129.54181818181817
